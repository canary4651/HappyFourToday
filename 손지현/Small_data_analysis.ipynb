# %%
import pandas as pd

# %%
my_data = pd.read_csv('sdata.csv')

# %%
my_data
# Out:
#     date member  score                     comment      health  sleep_score  \
# 0    8/2    손지현      7                         NaN         NaN            3
# 1    8/3    손지현     10       컨프런스에서 (무거운) 책 받았다!!!         NaN            8
# 2    8/4    손지현      9  오늘 집에서 한발자국도 안 나갔다. 행복해...         NaN            7
# 3    8/5    손지현      4                     수업 어렵당ㅜ         NaN            5
# 4    8/6    손지현      7                     두부맛집 갔당        건강검진            7
# 5    8/7    손지현      8                          술술         NaN            4
# 6    8/8    손지현      7                          무난         NaN            4
# 7    8/9    손지현      7                          으앙         NaN            7
# 8   8/10    손지현      8                부모님이랑 노래방 갔당         NaN            8
# 9   8/11    손지현      8                 친구들이랑 놀러다녔당         NaN            6
# 10  8/12    손지현      7                    판다스.....         NaN            6
# ...

# %%
my_data(['sleep_time'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-98359ea541cc> in <module>
# ----> 1 my_data(['sleep_time'])
#
# TypeError: 'DataFrame' object is not callable

# %%
my_data.corr()
# Out:
#                 score  sleep_score  education     study      rest    family  \
# score        1.000000     0.439797   0.329140  0.057143 -0.461880 -0.161165
# sleep_score  0.439797     1.000000   0.127515  0.104328  0.039528  0.585369
# education    0.329140     0.127515   1.000000 -0.602018 -1.000000       NaN
# study        0.057143     0.104328  -0.602018  1.000000 -0.572093  0.674200
# rest        -0.461880     0.039528  -1.000000 -0.572093  1.000000       NaN
# family      -0.161165     0.585369        NaN  0.674200       NaN  1.000000
# friend       0.522233     0.752618        NaN       NaN  0.000000       NaN
# reading      0.107244     0.569811  -0.301511  0.058443  0.380551  0.866025
# shopping          NaN          NaN        NaN       NaN       NaN       NaN
# snack        1.000000     1.000000        NaN       NaN       NaN       NaN
# meal        -0.309213     0.093545  -0.441511  0.017946  0.325134       NaN
# ...

# %%
import seaborn as sns

# %%
from matplotlib import pyplot as plt

# %%
sns.heatmap(my_data.corr(), annot=True, fmt = '.1f', linewidths=0.1)
plt.show()

# %%
set1 = sns.palplot(sns.color_palette("Paired"))

# %%
plt.figure(figsize=(15, 10))
sns.heatmap(my_data.corr(), annot=True, fmt = '.2f', linewidths=0.2, cmap= 'GnBu')
plt.show()

# %%
sns.distplot.my_data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-f2bf39cee1f3> in <module>
# ----> 1 sns.distplot.my_data
#
# AttributeError: 'function' object has no attribute 'my_data'
